# %%
import pandas as pd
import sklearn
import matplotlib as plt

# %%
df_old = pd.read_csv('merged_data_16_24.csv', low_memory=False)

# %%
df_25 = pd.read_csv('merged_gw_24_25.csv', low_memory=False, on_bad_lines='skip')

# %%
df_current = pd.read_csv('merged_gw_25-26_gw9.csv', low_memory=False)

# %%
df_old.head()
# Out:
#   season_x                name position team_x  assists  bonus  bps  \
# 0  2016-17     Aaron Cresswell      DEF    NaN        0      0    0
# 1  2016-17        Aaron Lennon      MID    NaN        0      0    6
# 2  2016-17        Aaron Ramsey      MID    NaN        0      0    5
# 3  2016-17  Abdoulaye Doucouré      MID    NaN        0      0    0
# 4  2016-17   Abdul Rahman Baba      DEF    NaN        0      0    0
#
#    clean_sheets  creativity  element  ...  team_h_score  threat  total_points  \
# 0             0         0.0      454  ...             2       0             0
# 1             0         0.3      142  ...             1       0             1
# 2             0         4.9       16  ...             3      23             2
# 3             0         0.0      482  ...             1       0             0
# 4             0         0.0       80  ...             2       0             0
#
#    transfers_balance  transfers_in transfers_out  value  was_home  \
# 0                  0             0             0     55     False
# 1                  0             0             0     60      True
# 2                  0             0             0     80      True
# 3                  0             0             0     50     False
# 4                  0             0             0     55      True
#
#   yellow_cards  GW
# 0            0   1
# 1            0   1
# 2            0   1
# 3            0   1
# 4            0   1
#
# [5 rows x 37 columns]

# %%
df_25.head()
# Out:
#                                name position            team   xP  assists  \
# 0                        Alex Scott      MID     Bournemouth  1.6        0
# 1  Carlos Miguel dos Santos Pereira       GK   Nott'm Forest  2.2        0
# 2                 Tomiyasu Takehiro      DEF         Arsenal  0.0        0
# 3                   Malcolm Ebiowei      MID  Crystal Palace  0.0        0
# 4                 Ben Brereton Díaz      MID     Southampton  1.0        0
#
#    bonus  bps  clean_sheets  creativity  element  ...  team_h_score  threat  \
# 0      0   11             0        12.8       77  ...             1     0.0
# 1      0    0             0         0.0      427  ...             1     0.0
# 2      0    0             0         0.0       22  ...             2     0.0
# 3      0    0             0         0.0      197  ...             2     0.0
# 4      0   -2             0        14.0      584  ...             1    16.0
#
#    total_points  transfers_balance  transfers_in  transfers_out  value  \
# 0             2                  0             0              0     50
# 1             0                  0             0              0     45
# 2             0                  0             0              0     50
# 3             0                  0             0              0     45
# 4             1                  0             0              0     55
#
#    was_home  yellow_cards GW
# 0     False             0  1
# 1      True             0  1
# 2      True             0  1
# 3     False             0  1
# 4     False             1  1
#
# [5 rows x 42 columns]

# %%
df_current.head()
# Out:
#                     name position           team   xP  assists  bonus  bps  \
# 0        Elliot Anderson      MID  Nott'm Forest  2.0        1      1   24
# 1        James Tarkowski      DEF        Everton  3.8        0      0    7
# 2          Ollie Watkins      FWD    Aston Villa  2.3        0      0   12
# 3          Iliman Ndiaye      MID        Everton  2.7        0      0   11
# 4  Charalampos Kostoulas      FWD       Brighton  1.4        0      0    0
#
#    clean_sheets  clearances_blocks_interceptions  creativity  ...  \
# 0             0                                1        21.3  ...
# 1             0                               13         2.1  ...
# 2             1                                2        12.2  ...
# 3             0                                1        12.1  ...
# 4             0                                0         0.0  ...
#
#    team_h_score  threat  total_points  transfers_balance  transfers_in  \
# 0             3    20.0             6                  0             0
# 1             1     7.0             4                  0             0
# 2             0    27.0             2                  0             0
# 3             1     2.0             2                  0             0
# 4             1     0.0             0                  0             0
#
#    transfers_out  value  was_home  yellow_cards  GW
# 0              0     55      True             0   1
# 1              0     55     False             0   1
# 2              0     90      True             0   1
# 3              0     65     False             0   1
# 4              0     50      True             0   1
#
# [5 rows x 46 columns]

# %%
df_old.columns
# Out:
# Index(['season_x', 'name', 'position', 'team_x', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'fixture', 'goals_conceded',
#        'goals_scored', 'ict_index', 'influence', 'kickoff_time', 'minutes',
#        'opponent_team', 'opp_team_name', 'own_goals', 'penalties_missed',
#        'penalties_saved', 'red_cards', 'round', 'saves', 'selected',
#        'team_a_score', 'team_h_score', 'threat', 'total_points',
#        'transfers_balance', 'transfers_in', 'transfers_out', 'value',
#        'was_home', 'yellow_cards', 'GW'],
#       dtype='object')

# %%
df_25.columns
# Out:
# Index(['name', 'position', 'team', 'xP', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals',
#        'expected_goals_conceded', 'fixture', 'goals_conceded', 'goals_scored',
#        'ict_index', 'influence', 'kickoff_time', 'minutes', 'modified',
#        'opponent_team', 'own_goals', 'penalties_missed', 'penalties_saved',
#        'red_cards', 'round', 'saves', 'selected', 'starts', 'team_a_score',
#        'team_h_score', 'threat', 'total_points', 'transfers_balance',
#        'transfers_in', 'transfers_out', 'value', 'was_home', 'yellow_cards',
#        'GW'],
#       dtype='object')

# %%
df_current.columns
# Out:
# Index(['name', 'position', 'team', 'xP', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'clearances_blocks_interceptions', 'creativity',
#        'defensive_contribution', 'element', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals',
#        'expected_goals_conceded', 'fixture', 'goals_conceded', 'goals_scored',
#        'ict_index', 'influence', 'kickoff_time', 'minutes', 'modified',
#        'opponent_team', 'own_goals', 'penalties_missed', 'penalties_saved',
#        'recoveries', 'red_cards', 'round', 'saves', 'selected', 'starts',
#        'tackles', 'team_a_score', 'team_h_score', 'threat', 'total_points',
#        'transfers_balance', 'transfers_in', 'transfers_out', 'value',
#        'was_home', 'yellow_cards', 'GW'],
#       dtype='object')

# %%
# Fixing the DATASETS renaming and peprare to combine

# %%
df_old.rename(columns={'team_x': 'team', 'season_x': 'season'}, inplace=True)

# %%
df_25['season'] = '2024-25'
df_current['season'] = '2025-26'

# %%
df_old.columns
# Out:
# Index(['season', 'name', 'position', 'team', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'fixture', 'goals_conceded',
#        'goals_scored', 'ict_index', 'influence', 'kickoff_time', 'minutes',
#        'opponent_team', 'opp_team_name', 'own_goals', 'penalties_missed',
#        'penalties_saved', 'red_cards', 'round', 'saves', 'selected',
#        'team_a_score', 'team_h_score', 'threat', 'total_points',
#        'transfers_balance', 'transfers_in', 'transfers_out', 'value',
#        'was_home', 'yellow_cards', 'GW'],
#       dtype='object')

# %%
df_25.columns
# Out:
# Index(['name', 'position', 'team', 'xP', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals',
#        'expected_goals_conceded', 'fixture', 'goals_conceded', 'goals_scored',
#        'ict_index', 'influence', 'kickoff_time', 'minutes', 'modified',
#        'opponent_team', 'own_goals', 'penalties_missed', 'penalties_saved',
#        'red_cards', 'round', 'saves', 'selected', 'starts', 'team_a_score',
#        'team_h_score', 'threat', 'total_points', 'transfers_balance',
#        'transfers_in', 'transfers_out', 'value', 'was_home', 'yellow_cards',
#        'GW', 'season'],
#       dtype='object')

# %%
df_current.columns
# Out:
# Index(['name', 'position', 'team', 'xP', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'clearances_blocks_interceptions', 'creativity',
#        'defensive_contribution', 'element', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals',
#        'expected_goals_conceded', 'fixture', 'goals_conceded', 'goals_scored',
#        'ict_index', 'influence', 'kickoff_time', 'minutes', 'modified',
#        'opponent_team', 'own_goals', 'penalties_missed', 'penalties_saved',
#        'recoveries', 'red_cards', 'round', 'saves', 'selected', 'starts',
#        'tackles', 'team_a_score', 'team_h_score', 'threat', 'total_points',
#        'transfers_balance', 'transfers_in', 'transfers_out', 'value',
#        'was_home', 'yellow_cards', 'GW', 'season'],
#       dtype='object')

# %%
# keeping only the must have columns

# %%
common_columns = ['name', 'position', 'team', 'season', 'GW',
                 'minutes', 'total_points', 'value', 'selected',
                 'goals_scored', 'assists', 'clean_sheets', 'goals_conceded',
                 'own_goals', 'penalties_saved', 'penalties_missed', 'yellow_cards', 'red_cards',
                  'saves', 'bonus', 'bps', 'influence', 'creativity', 'threat', 'ict_index',
                  'transfers_balance', 'transfers_in', 'transfers_out',
                  'team_h_score', 'team_a_score', 'was_home', 'opponent_team', 'fixture', 'round', 'element'
                 ]

# %%
# Filtering and merging

# %%
df_part1 = df_old[common_columns]
df_part2 = df_25[common_columns]
df_part3 = df_current[common_columns]

# %%
final_df = pd.concat([df_part1, df_part2, df_part3], axis=0, ignore_index=True)

# %%
# Filtering out the old seasons

# %%
seasons_to_keep = ['2021-22', '2022-23', '2023-24', '2024-25', '2025-26']

# %%
final_df = final_df[final_df['season'].isin(seasons_to_keep)]

# %%
#exporting and saving the new file

# %%
final_df.to_csv('final_fpl_dataset.csv', index=False)
print(f"Sucess! {len(final_df)} rows.")
print("columns:", list(final_df.columns))
# Out:
# Sucess! 101676 rows.
# columns: ['name', 'position', 'team', 'season', 'GW', 'minutes', 'total_points', 'value', 'selected', 'goals_scored', 'assists', 'clean_sheets', 'goals_conceded', 'own_goals', 'penalties_saved', 'penalties_missed', 'yellow_cards', 'red_cards', 'saves', 'bonus', 'bps', 'influence', 'creativity', 'threat', 'ict_index', 'transfers_balance', 'transfers_in', 'transfers_out', 'team_h_score', 'team_a_score', 'was_home', 'opponent_team', 'fixture', 'round', 'element']
